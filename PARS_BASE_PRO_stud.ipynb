# %% [markdown]
# <a href="https://colab.research.google.com/github/VayLorm/ServerManagment/blob/main/PARS_BASE_PRO_stud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Парсинг с помощью BeautifulSoup

# %% [markdown]
# Beautiful Soup - это библиотека для Python, которая позволяет парсить (анализировать) HTML и XML документы. Она предоставляет удобный способ искать, навигировать, и модифицировать дерево DOM (Document Object Model), представляющее HTML/XML документ.

# %% [markdown]
# # Задание

# %% [markdown]
# Вам необходимо собрать датасет, спарсив данные из этого сайта:
#
# https://books.toscrape.com/
#
# Всего на сайте 1000 книг. То есть длина датасета должна равняться количеству книг.
#
# Итоговая таблица должна содержать следующие столбцы:
#
# | Название столбца | Описание |
# |--|--|
# |id| Идентификатор книги |
# |book_name| Название книги |
# |price| Цена в £ |
# |stock| Наличие книги. 1 или 0|
# |url| Ссылка на книгу |
#
# **Примечание по столбцам:**
# - `id` - заполняется разработчиком датасета. Первая спарсенная книга имеет `id` = `0`.
# - `url` - должна содержать полную ссылку. Не только конец ссылки, указанный на сайте. То есть по данному url можно перейти одним кликом.

# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from IPython.display import HTML

# %% [markdown]
# ## Cоздание датасета и парсинг данных

# %%
# Создадим переменную и поместим в нее адрес сайта
url = 'https://books.toscrape.com/'

# %%
# Создадим переменную для получения ответа от сайта
page = requests.get(url, timeout=10)
page
# Out:
# <Response [200]>

# %%
# Создадим переменную для запросов к сайту
if page.status_code == 200:
    soup = BeautifulSoup(page.text, features='html.parser')
else:
    soup = None

# soup = BeautifulSoup(page.text, "html.parser")

# %%
# Создадим датафрейм
df = pd.DataFrame({
    'id':[],
    'book_name':[],
    'price':[],
    'stock':[],
    'url':[],
})

# %%
# Функция для записи значений, спарсенных с одной страницы, в датафрейм через словарь
def get_quotes(soup, data=df):

    divs = soup.find_all('article', {'class':['product_pod']})
    url = 'https://books.toscrape.com/catalogue/'

    for div in divs:
        quote = {}

        quote['book_name'] = div.findNext('img').get('alt')
        quote['price'] = div.find('p', class_='price_color').text

        if div.find('p', class_='instock availability').text == '\n\n    \n        In stock\n    \n':
            quote['stock'] = 1
        else:
            quote['stock'] = 1
        quote['url'] = url + div.find('a').get('href')[6:]

        df.loc[len(df)] = quote

# %%
# Применение функции  get_quotes() ко всем страницам с данными
url = 'https://books.toscrape.com/catalogue/category/books_1/page-'

for i in range(1, 60):
    print(f'Page N:{i}')
    r = requests.get(url + str(i) + '.html', timeout=10)
    print(url + str(i) + '.html')
    soup = BeautifulSoup(r.content, 'html.parser')

    get_quotes(soup, df)

    if '404 Not Found' in soup.text:
        break
# Out:
# Page N:1
# https://books.toscrape.com/catalogue/category/books_1/page-1.html
# Page N:2
# https://books.toscrape.com/catalogue/category/books_1/page-2.html
# Page N:3
# https://books.toscrape.com/catalogue/category/books_1/page-3.html
# Page N:4
# https://books.toscrape.com/catalogue/category/books_1/page-4.html
# Page N:5
# https://books.toscrape.com/catalogue/category/books_1/page-5.html
# Page N:6
# https://books.toscrape.com/catalogue/category/books_1/page-6.html
# Page N:7
# https://books.toscrape.com/catalogue/category/books_1/page-7.html
# Page N:8
# https://books.toscrape.com/catalogue/category/books_1/page-8.html
_html(render_links=True, escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>book_name</th>
#       <th>price</th>
#       <th>stock</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>A Light in the Attic</td>
#       <td>£51.77</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html" target="_blank">https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Tipping the Velvet</td>
#       <td>£53.74</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html" target="_blank">https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Soumission</td>
#       <td>£50.10</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/soumission_998/index.html" target="_blank">https://books.toscrape.com/catalogue/soumission_998/index.html</a></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>Sharp Objects</td>
#       <td>£47.82</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/sharp-objects_997/index.html" target="_blank">https://books.toscrape.com/catalogue/sharp-objects_997/index.html</a></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>Sapiens: A Brief History of Humankind</td>
#       <td>£54.23</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html" target="_blank">https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html</a></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>The Requiem Red</td>
#       <td>£22.65</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/the-requiem-red_995/index.html" target="_blank">https://books.toscrape.com/catalogue/the-requiem-red_995/index.html</a></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>The Dirty Little Secrets of Getting Your Dream Job</td>
#       <td>£33.34</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html" target="_blank">https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html</a></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull</td>
#       <td>£17.93</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html" target="_blank">https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html</a></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics</td>
#       <td>£22.60</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html" target="_blank">https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html</a></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>The Black Maria</td>
#       <td>£52.15</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/the-black-maria_991/index.html" target="_blank">https://books.toscrape.com/catalogue/the-black-maria_991/index.html</a></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10</td>
#       <td>Starving Hearts (Triangular Trade Trilogy, #1)</td>
#       <td>£13.99</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html" target="_blank">https://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html</a></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>11</td>
#       <td>Shakespeare's Sonnets</td>
#       <td>£20.66</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html" target="_blank">https://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html</a></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>Set Me Free</td>
#       <td>£17.46</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/set-me-free_988/index.html" target="_blank">https://books.toscrape.com/catalogue/set-me-free_988/index.html</a></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)</td>
#       <td>£52.29</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html" target="_blank">https://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html</a></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>Rip it Up and Start Again</td>
#       <td>£35.02</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html" target="_blank">https://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html</a></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>15</td>
#       <td>Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991</td>
#       <td>£57.25</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html" target="_blank">https://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html</a></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>16</td>
#       <td>Olio</td>
#       <td>£23.88</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/olio_984/index.html" target="_blank">https://books.toscrape.com/catalogue/olio_984/index.html</a></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>17</td>
#       <td>Mesaerion: The Best Science Fiction Stories 1800-1849</td>
#       <td>£37.59</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html" target="_blank">https://books.toscrape.com/catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html</a></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>18</td>
#       <td>Libertarianism for Beginners</td>
#       <td>£51.33</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html" target="_blank">https://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html</a></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>19</td>
#       <td>It's Only the Himalayas</td>
#       <td>£45.17</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html" target="_blank">https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html</a></td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>20</td>
#       <td>In Her Wake</td>
#       <td>£12.84</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/in-her-wake_980/index.html" target="_blank">https://books.toscrape.com/catalogue/in-her-wake_980/index.html</a></td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>21</td>
#       <td>How Music Works</td>
#       <td>£37.32</td>
#       <td>1</td>
#       <td><a href="https://books.toscrape.com/catalogue/how-music-wo

# %% [markdown]
# ## Итоговый датасет

# %%
df.shape
# Out:
# (1000, 5)

# %%
display(
    df.head(),
    df.tail()
)
# Out:
#   id                              book_name   price  stock  \
# 0  0                   A Light in the Attic  £51.77      1
# 1  1                     Tipping the Velvet  £53.74      1
# 2  2                             Soumission  £50.10      1
# 3  3                          Sharp Objects  £47.82      1
# 4  4  Sapiens: A Brief History of Humankind  £54.23      1
#
#                                                  url
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...
#       id                                          book_name   price  stock  \
# 995  995  Alice in Wonderland (Alice's Adventures in Won...  £55.53      1
# 996  996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  £57.06      1
# 997  997  A Spy's Devotion (The Regency Spies of London #1)  £16.97      1
# 998  998                1st to Die (Women's Murder Club #1)  £53.98      1
# 999  999                 1,000 Places to See Before You Die  £26.08      1
#
#                                                    url
# 995  https://books.toscrape.com/catalogue/alice-in-...
# 996  https://books.toscrape.com/catalogue/ajin-demi...
# 997  https://books.toscrape.com/catalogue/a-spys-de...
# 998  https://books.toscrape.com/catalogue/1st-to-di...
# 999  https://books.toscrape.com/catalogue/1000-plac...

# %% [markdown]
# # ЗАДАНИЕ ПРО

# %% [markdown]
# Так, мы спарсили данные о книгах. Но данные какие-то неполные. Часть названия стирается из-за отображения и нет ни полного названия книги, ни описания этой книги, ни жанра.
#
# Вам необходимо дополнить датасет, спарсив дополнительные данные из того же сайта:
#
# https://books.toscrape.com/
#
# Итоговая таблица должна содержать следующие столбцы:
#
# | Название столбца | Описание |
# |--|--|
# |id| Идентификатор книги |
# |book_name| Название книги - только полное название|
# |genre| жанр книги |
# |desc| описание |
# |price| Цена в £ |
# |stock| Наличие книги. 1 или 0|
# |url| Ссылка на книгу |
# | num_of_rev | количество отзывов|

# %% [markdown]
# ## Парсинг данных и обогащение датасета

# %%
# Функция для записи в soup адреса каждой продаваемой книги
def get_soup(url, **kwargs):
    response = requests.get(url, **kwargs)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, features='html.parser')
    else:
        soup = None
    return soup

# %%
# Добавление новых колонок в датафрейм и запись информации каждой продаваемой книги
from pandas.core.dtypes.astype import astype_array

for info in df.url:

    soup = get_soup(info)
    if soup is None:
        break

    if soup.find_all('div', class_='sub-header')[0].find('h2').contents[0] == 'Product Description':
        df.loc[df.url.str.contains(info), 'desc'] = np.array(soup.find_all('article')[0].find_all('p')[3])

    df.loc[df.url.str.contains(info), 'genre'] = soup.find_all('li')[2].find('a').contents[0]

    df.loc[df.url.str.contains(info), 'num_of_rev'] = soup.find_all(class_='table table-striped')[0].find_all('td')[6].text

df.desc = df.desc.fillna ('Данные отсутствуют')

# %%
df
# Out:
#       id                                          book_name   price  stock  \
# 0      0                               A Light in the Attic  £51.77      1
# 1      1                                 Tipping the Velvet  £53.74      1
# 2      2                                         Soumission  £50.10      1
# 3      3                                      Sharp Objects  £47.82      1
# 4      4              Sapiens: A Brief History of Humankind  £54.23      1
# ..   ...                                                ...     ...    ...
# 995  995  Alice in Wonderland (Alice's Adventures in Won...  £55.53      1
# 996  996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  £57.06      1
# 997  997  A Spy's Devotion (The Regency Spies of London #1)  £16.97      1
# 998  998                1st to Die (Women's Murder Club #1)  £53.98      1
# 999  999                 1,000 Places to See Before You Die  £26.08      1
#
#                                                    url  \
# 0    https://books.toscrape.com/catalogue/a-light-i...
# 1    https://books.toscrape.com/catalogue/tipping-t...
# 2    https://books.toscrape.com/catalogue/soumissio...
# 3    https://books.toscrape.com/catalogue/sharp-obj...
# 4    https://books.toscrape.com/catalogue/sapiens-a...
# ..                                                 ...
# 995  https://books.toscrape.com/catalogue/alice-in-...
# 996  https://books.toscrape.com/catalogue/ajin-demi...
# 997  https://books.toscrape.com/catalogue/a-spys-de...
# 998  https://books.toscrape.com/catalogue/1st-to-di...
# 999  https://books.toscrape.com/catalogue/1000-plac...
#
#                                                   desc               genre  \
# 0    It's hard to imagine a world without A Light i...              Poetry
# 1    "Erotic and absorbing...Written with starling ...  Historical Fiction
# 2    Dans une France assez proche de la nÃ´tre, un ...             Fiction
# 3    WICKED above her hipbone, GIRL across her hear...             Mystery
# 4    From a renowned historian comes a groundbreaki...             History
# ..                                                 ...                 ...
# 995                                 Данные отсутствуют            Classics
# 996  High school student Kei Nagai is struck dead i...      Sequential Art
# 997  In Englandâs Regency era, manners and elegan...  Historical Fiction
# 998  James Patterson, bestselling author of the Ale...             Mystery
# 999  Around the World, continent by continent, here...              Travel
#
#     num_of_rev
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 995          0
# 996          0
# 997          0
# 998          0
# 999          0
#
# [1000 rows x 8 columns]

# %%
# Выстроим столбцы в соответствии с заданием
df = df[['id', 'book_name', 'genre', 'desc', 'price', 'stock', 'url', 'num_of_rev']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   object
#  1   book_name   1000 non-null   object
#  2   genre       1000 non-null   object
#  3   desc        1000 non-null   object
#  4   price       1000 non-null   object
#  5   stock       1000 non-null   int64
#  6   url         1000 non-null   object
#  7   num_of_rev  1000 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 70.3+ KB

# %% [markdown]
# ## Итоговый датасет PRO

# %%
df.shape
# Out:
# (1000, 8)

# %%
display(
    df.head(),
    df.tail()
)
# Out:
#   id                              book_name               genre  \
# 0  0                   A Light in the Attic              Poetry
# 1  1                     Tipping the Velvet  Historical Fiction
# 2  2                             Soumission             Fiction
# 3  3                          Sharp Objects             Mystery
# 4  4  Sapiens: A Brief History of Humankind             History
#
#                                                 desc   price  stock  \
# 0  It's hard to imagine a world without A Light i...  £51.77      1
# 1  "Erotic and absorbing...Written with starling ...  £53.74      1
# 2  Dans une France assez proche de la nÃ´tre, un ...  £50.10      1
# 3  WICKED above her hipbone, GIRL across her hear...  £47.82      1
# 4  From a renowned historian comes a groundbreaki...  £54.23      1
#
#                                                  url num_of_rev
# 0  https://books.toscrape.com/catalogue/a-light-i...          0
# 1  https://books.toscrape.com/catalogue/tipping-t...          0
# 2  https://books.toscrape.com/catalogue/soumissio...          0
# 3  https://books.toscrape.com/catalogue/sharp-obj...          0
# 4  https://books.toscrape.com/catalogue/sapiens-a...          0
#       id                                          book_name  \
# 995  995  Alice in Wonderland (Alice's Adventures in Won...
# 996  996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997  997  A Spy's Devotion (The Regency Spies of London #1)
# 998  998                1st to Die (Women's Murder Club #1)
# 999  999                 1,000 Places to See Before You Die
#
#                   genre                                               desc  \
# 995            Classics                                 Данные отсутствуют
# 996      Sequential Art  High school student Kei Nagai is struck dead i...
# 997  Historical Fiction  In Englandâs Regency era, manners and elegan...
# 998             Mystery  James Patterson, bestselling author of the Ale...
# 999              Travel  Around the World, continent by continent, here...
#
#       price  stock                                                url  \
# 995  £55.53      1  https://books.toscrape.com/catalogue/alice-in-...
# 996  £57.06      1  https://books.toscrape.com/catalogue/ajin-demi...
# 997  £16.97      1  https://books.toscrape.com/catalogue/a-spys-de...
# 998  £53.98      1  https://books.toscrape.com/catalogue/1st-to-di...
# 999  £26.08      1  https://books.toscrape.com/catalogue/1000-plac...
#
#     num_of_rev
# 995          0
# 996          0
# 997          0
# 998          0
# 999          0
